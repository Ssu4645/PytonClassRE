# %%
#수학 모듈 (루트, 제곱등 여러연산)
import math
print (math.sqrt(16))
# Out:
# 4.0

# %%
# 시간 제어 모듈
import time
time.sleep(3)
print ("3초 후 실행")
# Out:
# 3초 후 실행

# %%
# random 임의의 수
import random
print (random.randint(1, 100))
# Out:
# 33

# %%
# datetime 현재 날짜와 시간출력
import datetime
print (datetime.datetime.now())

# %%
#시스템 모듛 (파이썬 실행환경을 다룸 ex 버전 확인 및 프로그램 종료)
import sys
print (sys.version)

# %%
#운영체제 모듈
import os
print (os.getcwd()) #현재 작업중인 폴더 경로 출력

# %%
# 데이터 형식 모듈 (JSON 형식으로 변환)
# JSON = ( "key" : "value" )
import json 

data = {
    "name" : "jin",
    "age" : 22    
}
print(json.dumps(data))
# Out:
# {"name": "jin", "age": 22}

# %%
#정규 표현식 모듈
#문자열 패턴 검사 모듈
import re
print (bool(re.match('hi', 'hi python'))) # 문자열이 hi로 시작하는지 확인
# Out:
# True

# %%
# CSV 파일 모듈
# CSV 파일을 읽고 쓰는 모듈 (데이터 저장분석 기초에 사용)
import csv
with open ('test.csv', 'w', newline = '') as f:
    csv.writer(f).writerow(['name', 'score'])

# %%
# 자료구조 모듈
# 자료구조를 편하게 사용할 수 있도록 도와줌

from collections import Counter
