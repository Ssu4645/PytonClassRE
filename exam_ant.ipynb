# %%
#어노테이션 : 어떤 타입인지 미리 적어두는 표시(자료형을 강제로 적용하지 않음)

#변수
age: int = 30
print(age)
#함수
def add(a:int, b:int) -> int:
    return a + b
print(10, 20)
#리스트
nums = list[int] = [1, 2, 3]
#딕셔너리
person: dict[str, int] = {
    "age" : 30,
    "height" : 180
}
# Out:
# 30
# 10 20
