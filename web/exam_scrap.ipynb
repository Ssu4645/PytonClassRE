# %%
# Out:
# <Response [200]>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       5 response = req.get("https://www.naver.com/")
#       6 print(response)
# ----> 8 soup = BeautifulSoup(html_doc, 'html.parser')
#       9 a_list = soup.select('a')
#      10 print(a_list)
#
# NameError: name 'html_doc' is not defined
