# %%
# 웹페이지 구성품
# HTML, CSS , JavaScript

# HTML은 웹페이지의 뼈대와 구조를 만드는 마크업 언어
# 태그
    #태그는 여는 태그, 닫는 태그가 세트로 존재
    #예외적으로 혼자 쓰는 태그 또한 존재
    #ex) <여는태그> 코드내용 <\닫는태그>

# 엘리먼트
# ex) <h1>제목<\h1>, <p> 내용 <\p>

# CSS는 웹 페이지의 디자인을 담당
# 선택자 : 태그, class, id

#JavaScript는 웹 페이지를 움직이게 하는 언어
