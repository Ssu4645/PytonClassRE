# %%
x = 10
y = 5
z = 0
z = x
x = y
y = z 
print ("x : ", x)
print ("y : ", y)
# Out:
# x :  5
# y :  10

# %%
x = 1
y = 2
# .format()
print("x : {}".format(x))
print("y : {}".format(y))
# f-string
print(f"{x}")
print(f"y : {y}")
# Out:
# x : 1
# y : 2
# 1
# y : 2

# %%
# list
# dictionary
# tuple
# set

# %%
# 자료형 변환 문제1
a = 10
b = 20
print (str(a) + str(b))
# 출력 => 1020
# Out:
# 1020

# %%
# 자료형 변환 문제2
a = '3'
b = '6'
print(int(a) + int(b))
# 출력 9
# Out:
# 9

# %%
# 자료형 변환 문제3 
a = '3.1'
b = '6.1'
print(float(a) + float(b))
# 출력 9.2
# Out:
# 9.2

# %%
# 자료형 변환 문제4
a = '3.1'
b = '6.1'
print(int(float(a)) + int(float(b)))
# 출력 9
# Out:
# 9

# %%
print("commit test")
print("commit test")
print("commit test")
# Out:
# commit test
# commit test
# commit test
